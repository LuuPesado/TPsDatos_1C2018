# %%
import datetime as dt
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error

# %%
ts = pd.read_csv('/home/luupesado/7506_Datos/2018/datos_tp/real_test/TrainingSet/Training_set1M.csv')
df100k_or = pd.read_csv('/home/luupesado/7506_Datos/2018/datos_tp/real_test/TestsSet/100k_as_ts1M.csv')

# %%
test= ts[0:15000]
train = ts[15000:]

# %%
crossValidation = pd.DataFrame()
crossValidation['sepostulo'] = test['sepostulo']
test = test.drop(['sepostulo'], axis = 1)

# %%
trainx = train.drop(['sepostulo'], axis = 1)
trainy = train['sepostulo']

# %%
del trainx['idaviso']
del trainx['idpostulante']
del test['idaviso']
del test['idpostulante']
del df100k_or['idaviso']
del df100k_or['idpostulante']

# %%
l = [0, 1000, 10000, 5000]

for i in l:
    regressor = DecisionTreeRegressor(max_features = 'log2', random_state = i)
    trainedSet = regressor.fit(trainx, trainy)
    predictions = trainedSet.predict(test)
    score = mean_squared_error(crossValidation['sepostulo'].values, predictions)
    print 'for l = ' + str(i) + 'score = ' + str(score)
# Out:
# for l = 0score = 0.37408411043
# for l = 1000score = 0.374144326322
# for l = 10000score = 0.374753922931
# for l = 5000score = 0.367533330963

# %%
for i in l:
    regressor = DecisionTreeRegressor(max_features = 'auto', random_state = i)
    trainedSet = regressor.fit(trainx, trainy)
    predictions = trainedSet.predict(test)
    score = mean_squared_error(crossValidation['sepostulo'].values, predictions)
    print 'for l = ' + str(i) + 'score = ' + str(score)
# Out:
# for l = 0score = 0.370757280263
# for l = 1000score = 0.368514354337
# for l = 10000score = 0.3680889423
# for l = 5000score = 0.36760018304

# %%
del df100k_or['id']

# %%
predictions = trainedSet.predict(df100k_or)

# %%
dic_knn = {'sepostulo': predictions}
df = pd.DataFrame.from_dict(dic_knn)
df['id'] = df.index
df['sepostula'] = df['sepostulo']
del df['sepostulo']
df['sepostulo'] = df['sepostula']
del df['sepostula']
df
# Out:
#           id  sepostulo
# 0          0        1.0
# 1          1        1.0
# 2          2        0.0
# 3          3        0.0
# 4          4        0.0
# 5          5        1.0
# 6          6        1.0
# 7          7        0.0
# 8          8        1.0
# 9          9        1.0
# 10        10        1.0
# 11        11        1.0
# 12        12        0.0
# 13        13        0.0
# 14        14        1.0
# 15        15        1.0
# 16        16        0.0
# 17        17        1.0
# 18        18        1.0
# 19        19        1.0
# 20        20        0.0
# 21        21        1.0
# 22        22        0.0
# 23        23        0.0
# 24        24        0.0
# 25        25        0.0
# 26        26        1.0
# 27        27        0.0
# 28        28        0.0
# 29        29        1.0
# ...      ...        ...
# 99970  99970        0.0
# 99971  99971        0.0
# 99972  99972        1.0
# 99973  99973        0.0
# 99974  99974        0.0
# 99975  99975        0.0
# ...

# %%
df['sepostulo'].value_counts()
# Out:
# 1.000000    55152
# 0.000000    42255
# 0.500000     1587
# 0.666667      412
# 0.750000      172
# 0.800000      109
# 0.333333       95
# 0.833333       53
# 0.857143       41
# 0.600000       37
# 0.900000       26
# 0.400000       17
# 0.250000       12
# 0.875000        9
# 0.888889        7
# 0.818182        3
# 0.714286        3
# 0.928571        3
# 0.909091        2
# 0.625000        2
# 0.166667        1
# 0.428571        1
# 0.923077        1
# Name: sepostulo, dtype: int64

# %%
df.to_csv('/home/luupesado/7506_Datos/2018/TPsDatos_1C2018/TP2/Submits/DecisionTreeRegressor_0.csv', index = False)

# %%
df['sepostulo'] = df['sepostulo'].apply(lambda x: x if x == 1 else 0)

# %%
df['sepostulo'].value_counts()
# Out:
# 1.0    55152
# 0.0    44848
# Name: sepostulo, dtype: int64

# %%
df.to_csv('/home/luupesado/7506_Datos/2018/TPsDatos_1C2018/TP2/Submits/DecisionTreeRegressor_0.csv', index = False)
