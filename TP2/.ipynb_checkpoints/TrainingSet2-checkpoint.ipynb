# %%
import pandas as pd
import numpy as np
# %pylab inline
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
datos = pd.read_csv('ArchivosDatos/Training_set_.csv')

# %%
datos.head()
# Out:
#    Unnamed: 0  ida     idaviso idpostulante  sepostulo  Unnamed: 0.1  \
# 0           0    0  1112257047      xke05Da          0         12530
# 1           1    1  1111920714       Y9lQVr          0         10137
# 2           2    2  1112346945       1MpolO          0          1356
# 3           3    3  1112345547      jk5DDEr          0           910
# 4           4    4  1112237522       EB23zz          0          7276
#
#    nombre_zona  tipo_de_trabajo  nivel_laboral  nombre_area  online  sexo  \
# 0            0                1              0            7       0     1
# 1            0                1              2           22       0     1
# 2            0                0              2           22       1     0
# 3            0                0              2           22       1     1
# 4            0                0              2            5       0     0
#
#    edad  nombre  estado  nombre-estado  anionacimiento  mesnacimiento  \
# ...

# %%
del datos['Unnamed: 0']

# %%
datos = datos.loc[:,['ida','idaviso','idpostulante','Unnamed: 0.1']]
datos.head()
# Out:
#    ida     idaviso idpostulante  Unnamed: 0.1
# 0    0  1112257047      xke05Da         12530
# 1    1  1111920714       Y9lQVr         10137
# 2    2  1112346945       1MpolO          1356
# 3    3  1112345547      jk5DDEr           910
# 4    4  1112237522       EB23zz          7276

# %%
datos.to_csv('ArchivosDatos/postulantes_y_avisos.csv')

# %%
datos = datos.rename(index=str,columns={'Unnamed: 0.1':'idp'})

# %%
datos = pd.read_csv('ArchivosDatos/Training_set_.csv')

# %%
datos = datos.rename(index=str, columns={'Unnamed: 0.1':'idp'})

# %%
datos.to_csv('ArchivosDatos/Training_set_2.csv',index=False)

# %%
del datos['idaviso']
del datos['idpostulante']
datos.head()
# Out:
#    Unnamed: 0  ida  sepostulo    idp  nombre_zona  tipo_de_trabajo  \
# 0           0    0          0  12530            0                1
# 1           1    1          0  10137            0                1
# 2           2    2          0   1356            0                0
# 3           3    3          0    910            0                0
# 4           4    4          0   7276            0                0
#
#    nivel_laboral  nombre_area  online  sexo  edad  nombre  estado  \
# 0              0            7       0     1    28       3       0
# 1              2           22       0     1    31       2       2
# 2              2           22       1     0    26       3       0
# 3              2           22       1     1    24       1       2
# 4              2            5       0     0    38       4       1
#
#    nombre-estado  anionacimiento  mesnacimiento  dianacimiento
# 0              9            1990              7              9
# ...

# %%
del datos['Unnamed: 0']
datos.set_index('sepostulo')
# Out:
#                ida    idp  nombre_zona  tipo_de_trabajo  nivel_laboral  \
# sepostulo
# 0                0  12530            0                1              0
# 0                1  10137            0                1              2
# 0                2   1356            0                0              2
# 0                3    910            0                0              2
# 0                4   7276            0                0              2
# 0                5    178            0                0              3
# 0                6   7079            0                0              3
# 0                7   4114            1                0              2
# 0                8   7498            0                0              2
# 0                9    NaN          NaN              NaN            NaN
# 0               10   7386            0                0              2
# 0               11  10539            0                0              2
# ...

# %%
datos.to_csv('ArchivosDatos/Training_set_3.csv')
